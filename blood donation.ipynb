# %% [markdown]
# <a href="https://colab.research.google.com/github/barathraj20/Predict-Blood-Donations/blob/master/blood%20donation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# data collection & analysis

# %%
# loading the data from csv file to a pandas dataframe
blood_dataset = pd.read_csv('/content/Blood Donors Details.csv')

# %%
# first 5 rows of the dataframe
blood_dataset.head()
# Out:
#            Timestamp                   Name Date of Birth  Age  Gender  \
# 0  9/2/2022 10:18:30            Bharathraj      9/16/2002   20    Male
# 1  9/2/2022 22:43:04                Ashwini     10/8/2002   19  Female
# 2   9/3/2022 0:57:30  RAJASREE THIRUMURUGAN      6/4/2003   19  Female
# 3   9/3/2022 1:00:21             Subiksha M      2/5/2003   19  Female
# 4   9/3/2022 1:01:56             S.Thirisaa     9/12/2002   19  Female
#
#                          Email  Mobile No.  \
# 0         sbarath067@gmail.com  9597269172
# 1      ashwinidurai8@gmail.com  7401179915
# 2      thirurajasree@gmail.com  9597157159
# 3  subikshamalaisamy@gmail.com  7904229232
# 4        thrizviolet@gmail.com  9361730242
#
#                                             Id Proof  \
# 0  https://drive.google.com/open?id=1wcxm2NYNyFoR...
# 1  https://drive.google.com/open?id=11AXtWZ3Xeqnv...
# 2                                                NaN
# 3  https://drive.google.com/open?id=1o31MQhqrfixq...
# ...

# %%
# number of rows and columns
blood_dataset.shape
# Out:
# (62, 23)

# %%
# getting some information about the dataset
blood_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 23 columns):
#  #   Column                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                  --------------  -----
#  0   Timestamp                                                                                                               62 non-null     object
#  1   Name                                                                                                                    62 non-null     object
#  2   Date of Birth                                                                                                           62 non-null     object
# ...

# %%
# checking for nmissing values
blood_dataset.isnull().sum()
# Out:
# Timestamp                                                                                                                  0
# Name                                                                                                                       0
# Date of Birth                                                                                                              0
# Age                                                                                                                        0
# Gender                                                                                                                     0
# Email                                                                                                                      0
# Mobile No.                                                                                                                 0
# ...

# %%
# statistical measures of the dataset
blood_dataset.describe()
# Out:
#              Age    Mobile No.  Enter Your Weight
# count  62.000000  6.200000e+01          48.000000
# mean   20.596774  9.687441e+09          56.875000
# std     4.782001  1.011934e+10          13.304335
# min    15.000000  6.369209e+09          32.000000
# 25%    19.000000  7.405411e+09          47.750000
# 50%    19.000000  8.609635e+09          54.500000
# 75%    20.000000  9.500134e+09          68.000000
# max    43.000000  8.754077e+10          95.000000

# %%
# distribution of age value
sns.set()
plt.figure(figsize=(5,5))
sns.distplot(blood_dataset['Age'])
plt.title('Age Distribution')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
